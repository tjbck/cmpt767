# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
metadata = pd.read_json("./meta.json")

# %%
beauty_reviews = pd.read_csv("./beauty.csv")
luxury_beauty_reviews = pd.read_csv("./luxury_beauty.csv")
fashion_reviews = pd.read_csv("./fashion.csv")
appliances_reviews = pd.read_csv("./appliances.csv")
industrial_reviews = pd.read_csv("./industrial.csv")
# Out:
# /var/folders/8w/29spy7853c158mzf537dcy800000gn/T/ipykernel_61822/2119844430.py:5: DtypeWarning: Columns (10,25,26,27,28,30,34,35,37,38,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   industrial_reviews = pd.read_csv("./industrial.csv")

# %%
beauty_reviews['category'] = 'beauty'
luxury_beauty_reviews['category'] = 'luxbeauty'
fashion_reviews['category'] = 'fashion'
appliances_reviews['category'] = 'appliances'
industrial_reviews['category'] = 'industrial'

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.8.3.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sentence-transformers>=0.3.8 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from keybert) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from keybert) (1.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from keybert) (1.26.2)
# Collecting rich>=10.4.0 (from keybert)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.4.0->keybert)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from rich>=10.4.0->keybert) (2.16.1)
# Requirement already satisfied: scipy>=1.5.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keybert) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keybert) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keybert) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (4.35.2)
# Requirement already satisfied: tqdm in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (2.1.1)
# Requirement already satisfied: torchvision in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (0.16.1)
# Requirement already satisfied: nltk in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (0.19.4)
# Requirement already satisfied: filelock in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.10.0)
# Requirement already satisfied: requests in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.8.0)
# Requirement already satisfied: packaging>=20.9 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: sympy in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.12)
# Requirement already satisfied: networkx in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.4.0)
# Requirement already satisfied: click in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/tim/miniconda3/envs/dev/lib/python3.11/site-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 2.5 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 3.8 MB/s eta 0:00:00
# Building wheels for collected packages: keybert
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.8.3-py3-none-any.whl size=39132 sha256=0b6690593d3a65524b71ab175cd66c57f70e93ba362cfcf475e2a21b5a6dab44
#   Stored in directory: /Users/tim/Library/Caches/pip/wheels/f7/0a/07/9dd07e4891a915b2f6311a73e0159e2858b27ec96e427e2b72
# Successfully built keybert
# Installing collected packages: mdurl, markdown-it-py, rich, keybert
# Successfully installed keybert-0.8.3 markdown-it-py-3.0.0 mdurl-0.1.2 rich-13.7.0

# %%
from keybert import KeyBERT

doc = """
         Supervised learning is the machine learning task of learning a function that
         maps an input to an output based on example input-output pairs. It infers a
         function from labeled training data consisting of a set of training examples.
         In supervised learning, each example is a pair consisting of an input object
         (typically a vector) and a desired output value (also called the supervisory signal).
         A supervised learning algorithm analyzes the training data and produces an inferred function,
         which can be used for mapping new examples. An optimal scenario will allow for the
         algorithm to correctly determine the class labels for unseen instances. This requires
         the learning algorithm to generalize from the training data to unseen situations in a
         'reasonable' way (see inductive bias).
      """
kw_model = KeyBERT()

# %%
i = 0
for review in beauty_reviews:
    print(review)
    i += 1
    if(i == 3):
        break
# Out:
#   Cell In[28], line 4
#     i++
#        ^
# SyntaxError: invalid syntax

# %%
review = beauty_reviews.loc[3]
keywords = kw_model.extract_keywords(f"{review['summary']} {review['reviewText']}") 
print(keywords)
# Out:
# [('aqua', 0.4109), ('lotion', 0.3909), ('shave', 0.3435), ('lotions', 0.3381), ('velva', 0.3103)]

# %%
luxury_beauty_reviews
# Out:
#        overall  verified   reviewTime      reviewerID        asin  \
# 0            5      True   01 5, 2018  A2HOI48JK8838M  B00004U9V2
# 1            5      True   04 5, 2017  A1YIPEY7HX73S7  B00004U9V2
# 2            5      True  03 27, 2017  A2QCGHIJ2TCLVP  B00004U9V2
# 3            5      True  03 20, 2017  A2R4UNHFJBA6PY  B00004U9V2
# 4            5      True  02 28, 2017  A2QCGHIJ2TCLVP  B00004U9V2
# ...        ...       ...          ...             ...         ...
# 19994        5     False  10 24, 2015   AYO1146CBIV5C  B0089HGSMK
# 19995        5     False  10 23, 2015  A3U5CZ3PV82JXD  B0089HGSMK
# 19996        5     False  10 22, 2015  A2NML53YCHS80S  B0089HGSMK
# 19997        5     False  10 21, 2015  A1ZCSSCAGBCD49  B0089HGSMK
# 19998        4     False  10 20, 2015  A2XNOB1T796Y6B  B0089HGSMK
#
#        style/Size:               reviewerName  \
# 0          0.9 oz.                         DB
# 1          3.5 oz.                      Ajaey
# 2            250 g                   D. Jones
# 3          3.5 oz.            Amazon Customer
# 4          0.9 oz.                   D. Jones
# ...            ...                        ...
# 19994   3.3 fl. oz          Michael Yovkovich
# 19995   3.3 fl. oz                   Danielle
# 19996   3.3 fl. oz            Burgundy Damsel
# 19997   3.3 fl. oz  I Dont Do Reviews Anymore
# 19998   3.3 fl. oz                  ChibiNeko
#
#                                               reviewText  \
# 0      This handcream has a beautiful fragrance. It d...
# 1      wonderful hand lotion, for seriously dry skin,...
# 2      Best hand cream around.  Silky, thick, soaks i...
# 3                                               Thanks!!
# 4      Great hand lotion.  Soaks right in and leaves ...
# ...                                                  ...
# 19994  Perfumes can be a hit or miss proposition when...
# 19995  I've smelled Burberry Brit before in departmen...
# 19996  I'm picky when it comes to perfumes, so I was ...
# 19997  BURBERRY Brit for Women Eau de Toilette, 3.3 f...
# 19998  I've tried the Burberry perfumes before, more ...
#
#                            summary  unixReviewTime  ...  image/8  \
# 0              Beautiful Fragrance      1515110400  ...      NaN
# 1            wonderful hand lotion      1491350400  ...      NaN
# 2           Best hand cream around      1490572800  ...      NaN
# 3                       Five Stars      1489968000  ...      NaN
# 4               Great hand lotion!      1488240000  ...      NaN
# ...                            ...             ...  ...      ...
# 19994            Excellent Perfume      1445644800  ...      NaN
# 19995                   Love this!      1445558400  ...      NaN
# 19996             My New Favorite!      1445472000  ...      NaN
# 19997  Wonderful scent for a woman      1445385600  ...      NaN
# 19998       A nice versatile scent      1445299200  ...      NaN
#
#       style/Format: style/Style Name: style/Style: style/Scent:  \
# 0               NaN               NaN          NaN          NaN
# 1               NaN               NaN          NaN          NaN
# 2               NaN               NaN          NaN          NaN
# 3               NaN               NaN          NaN          NaN
# 4               NaN               NaN          NaN          NaN
# ...             ...               ...          ...          ...
# 19994           NaN               NaN          NaN          NaN
# 19995           NaN               NaN          NaN          NaN
# 19996           NaN               NaN          NaN          NaN
# 19997           NaN               NaN          NaN          NaN
# 19998           NaN               NaN          NaN          NaN
#
#       style/Package Quantity: style/Flavor: style/Package Type:  \
# 0                         NaN           NaN                 NaN
# 1                         NaN           NaN                 NaN
# 2                         NaN           NaN                 NaN
# 3                         NaN           NaN                 NaN
# 4                         NaN           NaN                 NaN
# ...                       ...           ...                 ...
# 19994                     NaN           NaN                 NaN
# 19995                     NaN           NaN                 NaN
# 19996                     NaN           NaN                 NaN
# 19997                     NaN           NaN                 NaN
# 19998                     NaN           NaN                 NaN
#
#       style/Scent Name:   category
# 0                   NaN  luxbeauty
# 1                   NaN  luxbeauty
# 2                   NaN  luxbeauty
# 3                   NaN  luxbeauty
# 4                   NaN  luxbeauty
# ...                 ...        ...
# 19994               NaN  luxbeauty
# 19995               NaN  luxbeauty
# 19996               NaN  luxbeauty
# 19997               NaN  luxbeauty
# 19998               NaN  luxbeauty
#
# [19999 rows x 31 columns]

# %%
beauty_reviews.reviewerID.value_counts()
# Out:
# reviewerID
# AKJHHD5VEH7VG     12
# A1UQBFCERIP7VJ    12
# AUX122XW8ONG6     11
# A3NFZN1GS1RKR9    11
# A11QGZ39A7ZF0X    10
#                   ..
# A3U05BH8UYBNLE     5
# A21C5SBM0KCCH9     5
# ARI1N006KSXX       5
# A29PKN4LL05QGF     5
# A24HQ2N7332W7W     4
# Name: count, Length: 991, dtype: int64

# %%
beauty_reviews.loc[beauty_reviews['reviewerID'] == "AUX122XW8ONG6"]
# Out:
#       overall  verified   reviewTime     reviewerID        asin style/Size:  \
# 5058        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5059        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5060        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5061        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5062        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5063        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5264        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5265        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5266        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5267        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
# 5268        5      True  08 23, 2018  AUX122XW8ONG6  B01DLR9IDI         NaN
#
#      style/Flavor:    reviewerName  \
# 5058           NaN  Amzon Customer
# 5059           NaN  Amzon Customer
# 5060           NaN  Amzon Customer
# 5061           NaN  Amzon Customer
# 5062           NaN  Amzon Customer
# 5063           NaN  Amzon Customer
# 5264           NaN  Amzon Customer
# 5265           NaN  Amzon Customer
# 5266           NaN  Amzon Customer
# 5267           NaN  Amzon Customer
# 5268           NaN  Amzon Customer
#
#                                              reviewText              summary  \
# 5058  I love this refreshing eye cream! My sister bo...        Awesome Gift!
# 5059  Great product. I tried several products for my...             Liked it
# 5060  Exelent product! Generous amount in the packag...              Like it
# 5061  I love this product. I have dark circles under...                 Nice
# 5062  This Eye gel is great, I have allergies too ma...      Worth the money
# 5063  Bought it for my mother who has dark circles a...                Great
# 5264  I have genetic undereye darkness. Ive accepted...      Pretty Sweet!!!
# 5265                    I absolutely love this eye gel.        As advertised
# 5266  The eye gel is easy to apply and I use it morn...  I'm very happy with
# 5267                     Ok this eye gel is good stuff.     Does it's thing!
# 5268  This is the first eye gel/cream that actually ...                Happy
#
#       unixReviewTime vote image/0 image/1 style/Color: style/Scent Name:  \
# 5058      1534982400  NaN     NaN     NaN          NaN               NaN
# 5059      1534982400  NaN     NaN     NaN          NaN               NaN
# 5060      1534982400  NaN     NaN     NaN          NaN               NaN
# 5061      1534982400  NaN     NaN     NaN          NaN               NaN
# 5062      1534982400  NaN     NaN     NaN          NaN               NaN
# 5063      1534982400  NaN     NaN     NaN          NaN               NaN
# 5264      1534982400    2     NaN     NaN          NaN               NaN
# 5265      1534982400  NaN     NaN     NaN          NaN               NaN
# 5266      1534982400  NaN     NaN     NaN          NaN               NaN
# 5267      1534982400  NaN     NaN     NaN          NaN               NaN
# 5268      1534982400  NaN     NaN     NaN          NaN               NaN
#
#      image/2 style/Style Name:    style/Design:
# 5058     NaN               NaN   ETA-F4F7CA8275
# 5059     NaN               NaN   ETA-A76D0C9755
# 5060     NaN               NaN   ETA-A2D23DCD64
# 5061     NaN               NaN   ETA-F2C716495B
# 5062     NaN               NaN   ETA-B1EBECB839
# 5063     NaN               NaN   ETA-A14D63B301
# 5264     NaN               NaN   ETA-C6B5F7C374
# 5265     NaN               NaN   ETA-7117EE3788
# 5266     NaN               NaN   ETA-BF66BD2F87
# 5267     NaN               NaN   ETA-03868FCB34
# 5268     NaN               NaN   ETA-C4893097E9

# %%
metadata.loc[metadata['asin'] == "B00006L9LC"]
# Out:
#   category tech1                                        description fit  \
# 1       []        [<P><STRONG>Restores Moisture to Dehydrated Ha...
# 5       []        [<P><STRONG>Restores Moisture to Dehydrated Ha...
#
#                                            title  \
# 1  Citre Shine Moisture Burst Shampoo - 16 fl oz
# 5  Citre Shine Moisture Burst Shampoo - 16 fl oz
#
#                                             also_buy image tech2        brand  \
# 1  [B07CSVCGZV, B07KMGC13Z, B0793XJ4WW, B01N7U1HB...    []        Citre Shine
# 5  [B07CSVCGZV, B07KMGC13Z, B0793XJ4WW, B01N7U1HB...    []        Citre Shine
#
#   feature                                   rank also_view  \
# 1      []  1,693,702 in Beauty & Personal Care (        []
# 5      []  1,693,702 in Beauty & Personal Care (        []
#
#                                              details    main_cat similar_item  \
# 1  {'ASIN: ': 'B00006L9LC', 'UPC:': '795827187965...  All Beauty
# 5  {'ASIN: ': 'B00006L9LC', 'UPC:': '795827187965...  All Beauty
#
#   date   price        asin
# 1       $23.00  B00006L9LC
# 5       $23.00  B00006L9LC

# %%
asin_count = dict(beauty_reviews.value_counts('asin'))

# %%
for asin in asin_count:
    if(asin_count[asin]):
        print(asin, asin_count[asin])
        print(metadata.loc[metadata['asin'] == asin].brand)
# Out:
# B0012Y0ZG2 1794
# 33    Bath & Body Works
# Name: brand, dtype: object
# B000URXP6E 858
# 17    Bonne Bell
# Name: brand, dtype: object
# B001OHV1H4 489
# 44    Avalon
# Name: brand, dtype: object
# B00006L9LC 489
# 1    Citre Shine
# Name: brand, dtype: object
# B0009RF9DW 392
# 9    Yardley
# Name: brand, dtype: object
# B000FI4S1E 392
# 10    Fruits & Passion
# Name: brand, dtype: object
# B00W259T7G 163
# 79    Pre de Provence
# Name: brand, dtype: object
# B0010ZBORW 98
# 27    Urban Spa
# Name: brand, dtype: object
# B0013NB7DW 40
# 34    Williams
# Name: brand, dtype: object
# B001LNODUS 33
# 43    Pre de Provence
# Name: brand, dtype: object
# B019FWRG3C 33
# 82    Pre de Provence
# Name: brand, dtype: object
# B01E7UKR38 23
# 88
# Name: brand, dtype: object
# B00RZYW4RG 22
# 75    Sexy Hair
# Name: brand, dtype: object
# B019809F9Y 22
# 81    Williams
# Name: brand, dtype: object
# B01DLR9IDI 21
# 87
# Name: brand, dtype: object
# B00DY59MB6 18
# 62    Crest
# Name: brand, dtype: object
# B000NKJIXM 15
# 15    Crest
# Name: brand, dtype: object
# B000GLRREU 15
# 13    Waterpik
# Name: brand, dtype: object
# B000FOI48G 15
# 11    Waterpik
# Name: brand, dtype: object
# B00EYZY6LQ 14
# 64    Fekkai
# Name: brand, dtype: object
# B01BNEYGQU 13
# 85    Colgate
# Name: brand, dtype: object
# B001ET7FZE 13
# 41    Colgate
# Name: brand, dtype: object
# B00L1I1VMG 12
# 69    Crest
# Name: brand, dtype: object
# B00JF2GVWK 12
# 68    Caress
# Name: brand, dtype: object
# B007V6JNE0 10
# 53
# Name: brand, dtype: object
# B00QXW95Q4 10
# 74
# Name: brand, dtype: object
# B00N2WQ2IW 9
# 72    Pantene
# Name: brand, dtype: object
# B00HLXEXDO 9
# 66    E&O Essentials
# Name: brand, dtype: object
# B002GP80EU 9
# 46    Urban Spa
# Name: brand, dtype: object
# B00CQ0LN80 8
# 60    Victoria's Secret
# Name: brand, dtype: object
# B0017TZD7S 8
# 38    AXE PW
# Name: brand, dtype: object
# B008YQM4A6 8
# 54    Colgate
# Name: brand, dtype: object
# B000VV1YOY 8
# 20
# Name: brand, dtype: object
# B016V8YWBC 8
# 80    Dove
# Name: brand, dtype: object
# B00IJHY54S 8
# 67    Spongelle
# Name: brand, dtype: object
# B001E96LUO 7
# 40    Clean & Clear
# Name: brand, dtype: object
# B004CALFE4 7
# 48    BVLGARI
# Name: brand, dtype: object
# B00MTR49IG 7
# 71    Peter Lamas
# Name: brand, dtype: object
# B00B9V9ASM 6
# 58    Pantene
# Name: brand, dtype: object
# B0006O10P4 6
# 8    ZUM
# Name: brand, dtype: object
# B00VG1AV5Q 6
# 78    Thinkpichaidai
# Name: brand, dtype: object
# B019V2KYZS 6
# 84    Dolce & Gabbana
# Name: brand, dtype: object
# B00EF1QRMU 6
# 63    TNGY HAIR
# Name: brand, dtype: object
# B004KEJ65C 6
# 49    Folicure
# Name: brand, dtype: object
# B007R6UXNY 5
# 52    SoftSheen-Carson
# Name: brand, dtype: object
# B00AKP21KM 5
# 56    Pielor
# Name: brand, dtype: object
# B00BSE3III 5
# 59    Jhirmack
# Name: brand, dtype: object
# B00CZH3K1C 5
# 61    Crest
# Name: brand, dtype: object
# B006IB5T4W 5
# 50    Aquaphor
# Name: brand, dtype: object
# B00UWB35UY 5
# 76    Lucia
# Name: brand, dtype: object
# B00VARTPKS 5
# 77
# Name: brand, dtype: object
# B000LIBUBY 5
# 14    Fresh
# Name: brand, dtype: object
# B019LAI4HU 5
# 83    Michael Kors
# Name: brand, dtype: object
# B000VUXCGI 4
# 19    Maggie's Functional Organics
# Name: brand, dtype: object
# B000PKKAGO 4
# 16    Philips Norelco
# Name: brand, dtype: object
# B000FTYALG 4
# 12    Aqua Velva
# Name: brand, dtype: object
# B000V5Z4J6 4
# 18    Philips Sonicare
# Name: brand, dtype: object
# B0012XPRO8 4
# 32    Whish
# Name: brand, dtype: object
# B0000530HU 4
# 0    Aqua Velva
# Name: brand, dtype: object
# B001F51RAG 4
# 42    Oral-B
# Name: brand, dtype: object
# B00021DJ32 3
# 2    NARS
# Name: brand, dtype: object
# B0011FYB5I 3
# 29    Naturade
# Name: brand, dtype: object
# B001QY8QXM 3
# 45    Astra
# Name: brand, dtype: object
# B00126LYJM 2
# 31    The Hawaiian Classic Perfumes Collection
# Name: brand, dtype: object
# B0002JHI1I 2
# 3    Avalon
# Name: brand, dtype: object
# B0014SQQ3M 2
# 35    Fusion Beauty
# Name: brand, dtype: object
# B00155Z6V2 2
# 36    Organic Fiji
# Name: brand, dtype: object
# B00157OBRU 2
# 37    Nag Champa
# Name: brand, dtype: object
# B001E5PLCM 2
# 39    Clubman
# Name: brand, dtype: object
# B00120VWTK 2
# 30    Avalon Organics
# Name: brand, dtype: object
# B00112DRHY 2
# 28    Plantlife
# Name: brand, dtype: object
# B000X2FPXC 2
# 24    Dr. Woods
# Name: brand, dtype: object
# B002RZZXYE 2
# 47    Kate Somerville
# Name: brand, dtype: object
# B00NT0AR7E 2
# 73    OZ Naturals
# Name: brand, dtype: object
# B006WYJM8Y 2
# 51    NARS
# Name: brand, dtype: object
# B000X7ST9Y 2
# 25    AMERICAN CREW
# Name: brand, dtype: object
# B000W0C07Y 2
# 21    Instyle Parfums
# Name: brand, dtype: object
# B000WR2HB6 2
# 22    Wise Ways Herbals
# Name: brand, dtype: object
# B000WYJTZG 2
# 23    Helen Of Troy
# Name: brand, dtype: object
# B000YB70PS 2
# 26    KENT
# Name: brand, dtype: object
# B00MGK9Z8U 1
# 70    Rimmel
# Name: brand, dtype: object
# B0091OCA86 1
# 55    Andalou Naturals
# Name: brand, dtype: object
# B00B7V273E 1
# 57    Mad Hippie
# Name: brand, dtype: object
# B00GHJOM2U 1
# 65    Home Health
# Name: brand, dtype: object
# B01DKQAXC0 1
# 86
# Name: brand, dtype: object
